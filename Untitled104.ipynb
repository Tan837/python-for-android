# %% [markdown]
# <a href="https://colab.research.google.com/github/Tan837/python-for-android/blob/develop/Untitled104.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install buildozer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 84 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 10.7 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 468 kB 58.0 MB/s
# ...
#   Created wheel for sh: filename=sh-1.14.3-py2.py3-none-any.whl size=39654 sha256=c92e3624c8bde6a4b84a25ce2ec86622373cabb5cb614b6fc840cb208d715841
#   Stored in directory: /root/.cache/pip/wheels/3f/72/e2/2477a76f9fbf01a61b1dd9b34ff883288d6266d856461ba4d4
# Successfully built sh
# ...

# %%
# !pip install cython==0.29.32
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 18.04.6 LTS
# Release:	18.04
# Codename:	bionic

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# git is already the newest version (1:2.17.1-1ubuntu0.13).
# python3 is already the newest version (3.6.7-1~18.04).
# python3 set to manually installed.
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2.2).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# libavcodec-dev is already the newest version (7:3.4.11-0ubuntu0.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.11-0ubuntu0.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.11-0ubuntu0.1).
# libswscale-dev set to manually installed.
# ...

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0-dbg' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-gstreamer-1.0
#   gstreamer1.0-x intltool-debian libaa1 libarchive-cpio-perl
#   libarchive-zip-perl libcap2-bin libcdparanoia0 libdv4
#   libfile-stripnondeterminism-perl libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libmagic-mgc libmagic1 libmail-sendmail-perl
#   liborc-0.4-0 libpam-cap libshout3 libsigsegv2 libsys-hostname-long-perl
# ...

# %%
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libffi6 is already the newest version (3.2.1-8).
# libreadline-dev is already the newest version (7.0-3).
# libreadline-dev set to manually installed.
# bzip2 is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev set to manually installed.
# liblzma-dev is already the newest version (5.2.2-1.3ubuntu0.1).
# liblzma-dev set to manually installed.
# libsqlite3-dev is already the newest version (3.22.0-1ubuntu0.7).
# libsqlite3-dev set to manually installed.
# libssl-dev is already the newest version (1.1.1-1ubuntu2.1~18.04.20).
# openssl is already the newest version (1.1.1-1ubuntu2.1~18.04.20).
# openssl set to manually installed.
# uuid-dev is already the newest version (2.31.1-0.4ubuntu3.7).
# uuid-dev set to manually installed.
# ...

# %%
# !sudo apt-get install libffi-dev
# !sudo apt-get install automake
# !sudo apt-get install autoconf
# !sudo apt-get install libltdl-dev
# !sudo apt-get install libtool
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libffi-dev is already the newest version (3.2.1-8).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# automake is already the newest version (1:1.15.1-3ubuntu2).
# automake set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# autoconf is already the newest version (2.69-11).
# autoconf set to manually installed.
# ...

# %%
# !buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# File buildozer.spec created, ready to customize!

# %%
# !pip install kivmob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 31.3 MB 1.2 MB/s
# ...
#   Created wheel for kivmob: filename=kivmob-2.0-py3-none-any.whl size=4001 sha256=0e9af28a6a6153bdba9d4e8013826f050de67463773f3264e1fd424cf07d3b93
#   Stored in directory: /root/.cache/pip/wheels/38/63/49/d5658dad1e788e57b8a048cb5b7ecd647c806cef0a41926418
# Successfully built kivmob
# ...

# %%
# !buildozer -v android release
# Out:
# Streaming output truncated to the last 5000 lines.
# [INFO]:     - copy ./kivy/input/shape.pyc
# [INFO]:     - copy ./kivy/input/factory.pyc
# [INFO]:     - copy ./kivy/input/provider.pyc
# [INFO]:     - copy ./kivy/input/providers/androidjoystick.pyc
# [INFO]:     - copy ./kivy/input/providers/wm_touch.pyc
# [INFO]:     - copy ./kivy/input/providers/linuxwacom.pyc
# [INFO]:     - copy ./kivy/input/providers/wm_common.pyc
# [INFO]:     - copy ./kivy/input/providers/probesysfs.pyc
# [INFO]:     - copy ./kivy/input/providers/tuio.pyc
# [INFO]:     - copy ./kivy/input/providers/mtdev.pyc
# [INFO]:     - copy ./kivy/input/providers/__init__.pyc
# [INFO]:     - copy ./kivy/input/providers/mouse.pyc
# [INFO]:     - copy ./kivy/input/providers/mactouch.pyc
# [INFO]:     - copy ./kivy/input/providers/wm_pen.pyc
# [INFO]:     - copy ./kivy/input/providers/hidinput.pyc
# [INFO]:     - copy ./kivy/input/providers/leapfinger.pyc
# [INFO]:     - copy ./kivy/input/postproc/retaintouch.pyc
# ...

# %%
# !keytool -h
# Out:
# Key and Certificate Management Tool
#
# Commands:
#
#  -certreq            Generates a certificate request
#  -changealias        Changes an entry's alias
#  -delete             Deletes an entry
#  -exportcert         Exports certificate
#  -genkeypair         Generates a key pair
#  -genseckey          Generates a secret key
#  -gencert            Generates certificate from a certificate request
#  -importcert         Imports a certificate or a certificate chain
#  -importpass         Imports a password
#  -importkeystore     Imports one or all entries from another keystore
#  -keypasswd          Changes the key password of an entry
#  -list               Lists entries in a keystore
#  -printcert          Prints the content of a certificate
#  -printcertreq       Prints the content of a certificate request
#  -printcrl           Prints the content of a CRL file
#  -storepasswd        Changes the store password of a keystore
#
# Use "keytool -?, -h, or --help" for this help message
# ...

# %%
# !mkdir keystores

# %%
# !keytool -genkey -v -keystore keystores/kivyapp.keystore -alias kivyapp -sigalg SHA256withRSA -keyalg RSA -keysize 2048 -validity 10000
# Out:
# Enter keystore password:
# Re-enter new password:
# What is your first and last name?
#   [Unknown]:  Tanvir Ahmed
# What is the name of your organizational unit?
#   [Unknown]:  Soccer Lineup
# What is the name of your organization?
#   [Unknown]:  Soccer Lineup
# What is the name of your City or Locality?
#   [Unknown]:  Paterson
# What is the name of your State or Province?
#   [Unknown]:  New Jersey
# What is the two-letter country code for this unit?
#   [Unknown]:  US
# Is CN=Tanvir Ahmed, OU=Soccer Lineup, O=Soccer Lineup, L=Paterson, ST=New Jersey, C=US correct?
#   [no]:  yes
#
# Generating 2,048 bit RSA key pair and self-signed certificate (SHA256withRSA) with a validity of 10,000 days
# 	for: CN=Tanvir Ahmed, OU=Soccer Lineup, O=Soccer Lineup, L=Paterson, ST=New Jersey, C=US
# [Storing keystores/kivyapp.keystore]

# %%
# !keytool -importkeystore -srckeystore keystores/kivyapp.keystore -destkeystore keystores/kivyapp.keystore -deststoretype pkcs12
# Out:
# Enter source keystore password:
# Entry for alias kivyapp successfully imported.
# Import command completed:  1 entries successfully imported, 0 entries failed or cancelled
#
# ...
# The original keystore "keystores/kivyapp.keystore" is backed up as "keystores/kivyapp.keystore.old"...

# %%
# !keytool -list -keystore keystores/kivyapp.keystore -alias kivyapp -v -storepass Tanvirahmed047!
# Out:
# Alias name: kivyapp
# Creation date: Dec 3, 2022
# Entry type: PrivateKeyEntry
# Certificate chain length: 1
# Certificate[1]:
# Owner: CN=Tanvir Ahmed, OU=Soccer Lineup, O=Soccer Lineup, L=Paterson, ST=New Jersey, C=US
# Issuer: CN=Tanvir Ahmed, OU=Soccer Lineup, O=Soccer Lineup, L=Paterson, ST=New Jersey, C=US
# Serial number: 1a7122a3
# Valid from: Sat Dec 03 06:59:42 UTC 2022 until: Wed Apr 20 06:59:42 UTC 2050
# Certificate fingerprints:
# 	 SHA1: 82:79:0E:17:F3:46:11:2F:22:02:A0:9F:E7:23:46:0D:89:56:26:10
# 	 SHA256: 16:62:7C:56:39:FE:9D:67:4D:AD:DD:5A:57:27:9B:B4:0E:13:62:F4:D2:67:B0:42:A3:F0:2B:5D:A5:97:6A:32
# Signature algorithm name: SHA256withRSA
# Subject Public Key Algorithm: 2048-bit RSA key
# Version: 3
#
# Extensions:
#
# #1: ObjectId: 2.5.29.14 Criticality=false
# SubjectKeyIdentifier [
# KeyIdentifier [
# 0000: 7B BC DA 3D B1 7B 57 CC   E1 C1 19 8B E3 90 1B 30  ...=..W........0
# 0010: D8 4F 28 61                                        .O(a
# ]
# ]

# %%
# !cd bin && echo -ne "bin/"&&dir
# Out:
# bin/soccerlineup-0.1-arm64-v8a_armeabi-v7a-release.aab

# %%
# !jarsigner -keystore keystores/kivyapp.keystore bin/soccerlineup-0.1-arm64-v8a_armeabi-v7a-release.aab kivyapp
# Out:
# Enter Passphrase for keystore:
# jar signed.
#
# ...
# The signer's certificate is self-signed.

# %%
# !sudo apt update && sudo apt install android-sdk
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,348 kB]
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %%
# !zipalign -h
# Out:
# Zip alignment utility
# Copyright (C) 2009 The Android Open Source Project
#
# Usage: zipalign [-f] [-p] [-v] [-z] <align> infile.zip outfile.zip
#        zipalign -c [-p] [-v] <align> infile.zip
#
#   <align>: alignment in bytes, e.g. '4' provides 32-bit alignment
#   -c: check alignment only (does not modify file)
#   -f: overwrite existing outfile.zip
#   -p: memory page alignment for stored shared object files
#   -v: verbose output
#   -z: recompress using Zopfli

# %%
# !cd bin && echo -ne "bin/"&&dir
# Out:
# bin/soccerlineup-0.1-arm64-v8a_armeabi-v7a-release.aab

# %%
# !zipalign -v 4 bin/soccerlineup-0.1-arm64-v8a_armeabi-v7a-release.aab myapp-0.1-armeabi-v7a-release--optimized.aab
# Out:
# Verifying alignment of myapp-0.1-armeabi-v7a-release--optimized.aab (4)...
#       50 META-INF/MANIFEST.MF (OK - compressed)
#     7569 META-INF/KIVYAPP.SF (OK - compressed)
#    15921 META-INF/KIVYAPP.RSA (OK - compressed)
#    17103 BundleConfig.pb (OK - compressed)
#    17490 BUNDLE-METADATA/com.android.tools.build.libraries/dependencies.pb (OK - compressed)
#    21422 BUNDLE-METADATA/com.android.tools.build.gradle/app-metadata.properties (OK - compressed)
#    21552 base/assets/private.tar (OK - compressed)
#   410057 base/res/color/common_google_signin_btn_text_dark.xml (OK - compressed)
#   410492 base/res/color/common_google_signin_btn_text_light.xml (OK - compressed)
#   410921 base/res/color/common_google_signin_btn_tint.xml (OK - compressed)
#   411254 base/res/drawable/admob_close_button_black_circle_white_cross.xml (OK - compressed)
#   411821 base/res/drawable/admob_close_button_white_circle_black_cross.xml (OK - compressed)
# ...
